# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("../Data/시도별 전출입 인구수.xlsx")
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
df.tail()
# Out:
#     전출지별     전입지별  1970   1971   1972   1973   1974   1975   1976   1977  ...  \
# 320  NaN     전라북도   139    202    141    210    219    415    392    408  ...
# 321  NaN     전라남도   631    965    857    952   1133   2808   2608   2652  ...
# 322  NaN     경상북도   374    619    468    576    625   1123   1141   1004  ...
# 323  NaN     경상남도   474    479    440    571   1208   1517    863   1122  ...
# 324  NaN  제주특별자치도  9290  12427  12210  16158  19580  34221  23291  31028  ...
#
#       2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 320    668    579    672    561    551    516    609    683    733    768
# 321   1143   1123   1002   1026    966   1001    928   1062   1127   1102
# 322    761    704    738    756    699    781    728    903    931    994
# 323   1517   1474   1324   1367   1227   1278   1223   1500   1448   1501
# 324  59564  55673  55507  59846  54280  60607  59673  59036  66444  63275
#
# [5 rows x 50 columns]

# %%
df.isnull()
# Out:
#       전출지별   전입지별   1970   1971   1972   1973   1974   1975   1976   1977  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2     True  False  False  False  False  False  False  False  False  False
# 3     True  False  False  False  False  False  False  False  False  False
# 4     True  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 320   True  False  False  False  False  False  False  False  False  False
# 321   True  False  False  False  False  False  False  False  False  False
# 322   True  False  False  False  False  False  False  False  False  False
# 323   True  False  False  False  False  False  False  False  False  False
# 324   True  False  False  False  False  False  False  False  False  False
#
#      ...   2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전출지별    19 non-null     object
#  1   전입지별    325 non-null    object
#  2   1970    325 non-null    object
#  3   1971    325 non-null    object
#  4   1972    325 non-null    object
#  5   1973    325 non-null    object
#  6   1974    325 non-null    object
#  7   1975    325 non-null    object
#  8   1976    325 non-null    object
#  9   1977    325 non-null    object
#  10  1978    325 non-null    object
#  11  1979    325 non-null    object
#  12  1980    325 non-null    object
#  13  1981    325 non-null    object
#  14  1982    325 non-null    object
#  15  1983    325 non-null    object
#  16  1984    325 non-null    object
#  17  1985    325 non-null    object
#  18  1986    325 non-null    object
#  19  1987    325 non-null    object
#  20  1988    325 non-null    object
# ...

# %%
df["전출지별"].isnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 320     True
# 321     True
# 322     True
# 323     True
# 324     True
# Name: 전출지별, Length: 325, dtype: bool

# %%
# NaN을 전(prev) 데이터로 채움

df = df.fillna(method="ffill")
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2    전국  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3    전국  부산광역시    448577    389797    362202    482061    680984    805979
# 4    전국  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전출지별    325 non-null    object
#  1   전입지별    325 non-null    object
#  2   1970    325 non-null    object
#  3   1971    325 non-null    object
#  4   1972    325 non-null    object
#  5   1973    325 non-null    object
#  6   1974    325 non-null    object
#  7   1975    325 non-null    object
#  8   1976    325 non-null    object
#  9   1977    325 non-null    object
#  10  1978    325 non-null    object
#  11  1979    325 non-null    object
#  12  1980    325 non-null    object
#  13  1981    325 non-null    object
#  14  1982    325 non-null    object
#  15  1983    325 non-null    object
#  16  1984    325 non-null    object
#  17  1985    325 non-null    object
#  18  1986    325 non-null    object
#  19  1987    325 non-null    object
#  20  1988    325 non-null    object
# ...

# %% [markdown]
# ### 전출지별이 서울특별시, 전입지별이 서울특별시가 아닌경우
#
# : 서울에서 다른 지역으로 이동한 데이터 추출

# %%
df_seoul = df[(df["전출지별"] == "서울특별시") & (df["전입지별"] != "서울특별시")] # +하면 안되고 &써야함
len(df_seoul)
# Out:
# 17

# %%
# 전출지별 컬럼 삭제

del df_seoul["전출지별"]

df_seoul
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
# 전입지별 -> 전입지로 컬럼 변경

df_seoul.rename(columns={"전입지별" : "전입지"},inplace=True)
df_seoul
# Out:
#         전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
# 전입지가 전국, 부산광역시, 대구광역시 인것만 출력하기 (단, | 사용 금지) , isin쓰기

df_seoul[df_seoul["전입지"].isin(["전국","부산광역시","대구광역시"])]
# Out:
#       전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19     전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21  부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22  대구광역시        -        -        -        -        -        -        -
#
#        1977     1978  ...     2008     2009     2010     2011     2012  \
# 19  2678007  3028911  ...  2083352  1925452  1848038  1834806  1658928
# 21    27213    29856  ...    17353    17738    17418    18816    16135
# 22        -        -  ...     9720    10464    10277    10397    10135
#
#        2013     2014     2015     2016     2017
# 19  1620640  1661425  1726687  1655859  1571423
# 21    16153    17320    17009    15062    14484
# 22    10631    10062    10191     9623     8891
#
# [3 rows x 49 columns]

# %%
# df_seoul의 index를 전입지로 변경

df_seoul.set_index("전입지", inplace=True)
df_seoul.head()
# Out:
#           1970     1971     1972     1973     1974     1975     1976     1977  \
# 전입지
# 전국     1448985  1419016  1210559  1647268  1819660  2937093  2495620  2678007
# 부산광역시    11568    11130    11768    16307    22220    27515    23732    27213
# 대구광역시        -        -        -        -        -        -        -        -
# 인천광역시        -        -        -        -        -        -        -        -
# 광주광역시        -        -        -        -        -        -        -        -
#
#           1978     1979  ...     2008     2009     2010     2011     2012  \
# 전입지                      ...
# 전국     3028911  2441242  ...  2083352  1925452  1848038  1834806  1658928
# 부산광역시    29856    28542  ...    17353    17738    17418    18816    16135
# 대구광역시        -        -  ...     9720    10464    10277    10397    10135
# 인천광역시        -        -  ...    50493    45392    46082    51641    49640
# 광주광역시        -        -  ...    10846    11725    11095    10587    10154
#
# ...

# %%
# 서울에서 경기도로 이동한 인구 데이터 값만 선택

sr_one = df_seoul.loc["경기도"]
sr_one
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# 1975    253705
# 1976    202276
# 1977    207722
# 1978    237684
# 1979    278411
# 1980    297539
# 1981    252073
# 1982    320174
# 1983    400875
# 1984    352238
# 1985    390265
# 1986    412535
# 1987    405220
# 1988    415174
# 1989    412933
# 1990    473889
# 1991    384714
# 1992    428344
# 1993    502584
# 1994    542204
# 1995    599411
# 1996    520566
# 1997    495454
# 1998    407050
# 1999    471841
# 2000    435573
# 2001    499575
# 2002    516765
# 2003    457656
# 2004    400206
# 2005    414621
# 2006    449632
# 2007    431637
# 2008    412408
# 2009    398282
# 2010    410735
# 2011    373771
# 2012    354135
# 2013    340801
# 2014    332785
# 2015    359337
# 2016    370760
# 2017    342433
# Name: 경기도, dtype: object

# %%
type(sr_one)
# Out:
# pandas.core.series.Series

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
plt.plot(sr_one.index, sr_one.values)
plt.show()

# %%
# 차트 제목 추가

plt.plot(sr_one)
plt.title("서울 => 경기 인구 이동")

# 축 이름

plt.xlabel("연도")
plt.ylabel("이동 인구수")

plt.show()

# %% [markdown]
# ### 차트 꾸미기

# %%
# 차트 사이즈 지정(가로 14인치, 세로 5인치)
plt.figure(figsize=(14,5))

# x축 눈금 라벨 회전하기
plt.xticks(rotation=45)

# y축 눈금 라벨 회전하기
plt.yticks(rotation=45)

# 차트 제목 추가
plt.plot(sr_one)
plt.title("서울 => 경기 인구 이동")

# 축 이름
plt.xlabel("연도")
plt.ylabel("이동 인구수")

# 범례 표시
plt.legend(labels=["서울->경기"], loc = "best") # loc = "best"는 제일 좋은 위치로 들어가는 거

plt.show()

# %%
# 부산에서 서울 인구 이동 그래프 그리기

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("../Data/시도별 전출입 인구수.xlsx")
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
# NaN값 해결하기

df["전출지별"].isnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 320     True
# 321     True
# 322     True
# 323     True
# 324     True
# Name: 전출지별, Length: 325, dtype: bool

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2    전국  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3    전국  부산광역시    448577    389797    362202    482061    680984    805979
# 4    전국  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
# 전출지별이 부산광역시, 전입지별이 서울특별시인 경우 / 부산에서 서울 지역으로 이동한 데이터 추출

df_busan = df[(df["전출지별"] == "부산광역시") & (df["전입지별"] == "서울특별시")]
df_busan
# Out:
#      전출지별   전입지별   1970   1971   1972   1973   1974   1975   1976   1977  ...  \
# 38  부산광역시  서울특별시  24263  30144  18260  24251  30284  59914  43416  42685  ...
#
#      2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 38  25249  24459  23116  23016  21437  19621  20616  19441  19236  19460
#
# [1 rows x 50 columns]

# %%
len(df_busan)
# Out:
# 1

# %%
del df_busan["전출지별"]

# %%
df_busan.rename(columns={"전입지별" : "전입지"}, inplace=True)
df_busan
# Out:
#       전입지   1970   1971   1972   1973   1974   1975   1976   1977   1978  ...  \
# 38  서울특별시  24263  30144  18260  24251  30284  59914  43416  42685  48142  ...
#
#      2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 38  25249  24459  23116  23016  21437  19621  20616  19441  19236  19460
#
# [1 rows x 49 columns]

# %%
df_busan.set_index("전입지",inplace=True)

# %%
df_busan
# Out:
#         1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 서울특별시  24263  30144  18260  24251  30284  59914  43416  42685  48142  39673
#
#        ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지    ...
# 서울특별시  ...  25249  24459  23116  23016  21437  19621  20616  19441  19236
#
#         2017
# 전입지
# 서울특별시  19460
#
# [1 rows x 48 columns]

# %%
sr_one1 = df_busan.loc["서울특별시"]
sr_one1
# Out:
# 1970    24263
# 1971    30144
# 1972    18260
# 1973    24251
# 1974    30284
# 1975    59914
# 1976    43416
# 1977    42685
# 1978    48142
# 1979    39673
# 1980    44197
# 1981    49939
# 1982    50295
# 1983    54700
# 1984    47422
# 1985    41464
# 1986    35910
# 1987    35328
# 1988    37368
# 1989    36986
# 1990    34978
# 1991    29020
# 1992    29619
# 1993    29378
# 1994    26852
# 1995    25525
# 1996    24721
# 1997    24872
# 1998    23220
# 1999    27100
# 2000    28564
# 2001    28366
# 2002    28049
# 2003    26569
# 2004    24266
# 2005    24941
# 2006    26831
# 2007    26951
# 2008    25249
# 2009    24459
# 2010    23116
# 2011    23016
# 2012    21437
# 2013    19621
# 2014    20616
# 2015    19441
# 2016    19236
# 2017    19460
# Name: 서울특별시, dtype: object

# %%
# 차트 사이즈 지정(가로 14인치, 세로 5인치)
plt.figure(figsize=(14,5))

# x축 눈금 라벨 회전하기
plt.xticks(rotation=45)

# y축 눈금 라벨 회전하기
plt.yticks(rotation=45)

# 차트 제목 추가
plt.plot(sr_one)
plt.title("부산 => 서울 인구 이동")

# 축 이름
plt.xlabel("연도")
plt.ylabel("이동 인구수")

# 범례 표시
plt.legend(labels=["부산->서울"], loc = "best") # loc = "best"는 제일 좋은 위치로 들어가는 거

plt.show()

# %% [markdown]
# ---
# ### Style 적용하기

# %%
# Style 서식 지정
plt.style.use("ggplot") # 배경이 생김 / ggplot,grayscale/ 보통 ggplot을 많이씀

# 차트 사이즈 지정(가로 14인치, 세로 5인치)
plt.figure(figsize=(14,5))

# x축 눈금 라벨 회전하기
plt.xticks(rotation=45)

# y축 눈금 라벨 회전하기
plt.yticks(rotation=45)

# Marker 표시
plt.plot(sr_one, marker="o", markersize=10) # marker는 여러가지를 사용할 수 있다 ex) +, o, x등


# 차트 제목 추가
plt.title("서울 => 경기 인구 이동")

# 축 이름
plt.xlabel("연도", size=15)
plt.ylabel("이동 인구수", size=15)

# 범례 표시
plt.legend(labels=["서울->경기"], loc = "best", fontsize=20) # loc = "best"는 제일 좋은 위치로 들어가는 거 / legend 크기는 size가 아니라 fontsize로 크기 조절한다

# 저장하기
plt.savefig("../Data/seoul.png")

plt.show()

# %%
# stlye

plt.style.available # style 종류 확인할 수 있는 거
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html
#
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.annotate.html

# %% [markdown]
# ### Style 추가해보기

# %%
# Style 서식 지정
plt.style.use("ggplot") # 배경이 생김 / ggplot,grayscale/ 보통 ggplot을 많이씀

# 차트 사이즈 지정(가로 14인치, 세로 5인치)
plt.figure(figsize=(14,5))

# x축 눈금 라벨 회전하기
plt.xticks(rotation="vertical",size=10) # vertical은 90도

# y축 눈금 라벨 회전하기
plt.yticks(rotation=45)

# Marker 표시
plt.plot(sr_one, marker="o", markersize=10) # marker는 여러가지를 사용할 수 있다 ex) +, o, x등


# 차트 제목 추가
plt.title("서울 => 경기 인구 이동")

# 축 이름
plt.xlabel("연도", size=15)
plt.ylabel("이동 인구수", size=15)

# 범례 표시
plt.legend(labels=["서울->경기"], loc = "best", fontsize=20) # loc = "best"는 제일 좋은 위치로 들어가는 거 / legend 크기는 size가 아니라 fontsize로 크기 조절한다

# y축 범위 지정
plt.ylim(50000,800000)

# 주석 표시 - 화살표
plt.annotate(
    "",
    xy=(20,620000), # 화살표의 머리부분(끝점)
    xytext=(2,290000), # 화살표의 꼬리부분(시작점)
    xycoords="data", # 좌표체계
    arrowprops=dict(arrowstyle="->", color="skyblue", lw=5) # 화살표 서식
)
plt.annotate(
    "",
    xy=(47,450000), # 화살표의 머리부분(끝점)
    xytext=(25,650000), # 화살표의 꼬리부분(시작점)
    xycoords="data", # 좌표체계
    arrowprops=dict(arrowstyle="->", color="green", lw=5) # 화살표 서식
)

# 주석표시 - 텍스트
plt.annotate(
    "인구이동 증가(1970~1995)",
    xy=(10,400000),
    rotation=25, # 텍스트 각도
    va="baseline", # 상하정렬
    ha="center",
    fontsize=12
)
plt.annotate(
    "인구이동 감소(1995~2017)",
    xy=(35,600000),
    rotation=-10, # 텍스트 각도
    va="baseline", # 상하정렬
    ha="center",
    fontsize=12
)

# 저장하기
plt.savefig("../Data/seoul.png")

plt.show()

# %% [markdown]
# ---
# ### 화면분활하여 그래프 여러개 그리기

# %%
# warning 무시

import warnings
warnings.filterwarnings("ignore")

# %%
plt.style.use("ggplot")

# 그래프 객체 생성

fig = plt.figure(figsize=(10,10)) # 인스턴스 생성자 클래스
ax1 = fig.add_subplot(2,1,1) # 2행 1열의 1번째 그래프 / 2행1열의 칸을 만들어 놓고 몇번째에 넣을 건지
ax2 = fig.add_subplot(2,1,2) # 2행 1열의 2번째 그래프

ax1.plot(sr_one, "o", markersize=10)
ax2.plot(
    sr_one, 
    marker='o', 
    markersize=10, 
    markerfacecolor='green', 
    color='olive', 
    linewidth=2, 
    label='서울->경기'
)


ax2.legend(loc="best")

ax1.set_ylim(50000,800000)
ax2.set_ylim(50000,800000)

ax1.set_xticklabels(sr_one.index, rotation=75)
ax2.set_xticklabels(sr_one.index, rotation=75)

plt.show()

# %% [markdown]
# ### 동일한 그림에 여러개의 그래프르 추가

# %%
# 서울에서 다른 지역으로 이동한 데이터만 추출

mask = (df["전출지별"] == "서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop(["전출지별"], axis=1)
df_seoul.rename({"전입지별" : "전입지"}, axis=1, inplace=True)
df_seoul.set_index("전입지", inplace=True)
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %%
# 서울에서 충청남도, 경상북도, 강원도로 이동한 인구 데이터 값만 선택

df_3 = df_seoul.loc[["충청남도","경상북도","강원도","전라남도"],:]
df_3
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %%
# 칼럼이름 : 문자

list(range(2000,2018)) # 2000~2018년도 데이터만 추출
col_years = list(map(str,range(1970,2018))) # 2000~2018년도 데이터를 문자로 변환
col_years

# df_3 = df_seoul.loc[["충청남도","경상북도","강원도"],col_years] 범위를 지정해서 데이터를 뽑을때 예시
# Out:
# ['1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017']

# %%
plt.style.use("ggplot")

fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

ax.plot(
    df_3.columns,
    df_3.loc["충청남도"],
    marker="o",
    markerfacecolor="green",
    markersize=10,
    color="olive",
    linewidth=2,
    label="서울 -> 충남"
)
ax.plot(
    df_3.columns,
    df_3.loc["경상북도"],
    marker="o",
    markerfacecolor="blue",
    markersize=10,
    color="skyblue",
    linewidth=2,
    label="서울 -> 경북"
)
ax.plot(
    df_3.columns,
    df_3.loc["강원도"],
    marker="o",
    markerfacecolor="red",
    markersize=10,
    color="pink",
    linewidth=2,
    label="서울 -> 강원"
)

ax.legend(loc="best")
ax.set_title("서울 - > 충남, 경북, 강원 인구이동", size=20)
ax.set_xlabel("기간", size=12)
ax.set_ylabel("이동 인구수", size=12)
ax.set_xticklabels(df_3.columns, rotation=90)

plt.show()

# %%
plt.style.use("ggplot")

fig = plt.figure(figsize=(30,15))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot(
    df_3.columns,
    df_3.loc["충청남도"],
    marker="o",
    markerfacecolor="green",
    markersize=10,
    color="olive",
    linewidth=2,
    label="서울 -> 충남"
)
ax2.plot(
    df_3.columns,
    df_3.loc["경상북도"],
    marker="o",
    markerfacecolor="blue",
    markersize=10,
    color="skyblue",
    linewidth=2,
    label="서울 -> 경북"
)
ax3.plot(
    df_3.columns,
    df_3.loc["강원도"],
    marker="o",
    markerfacecolor="red",
    markersize=10,
    color="pink",
    linewidth=2,
    label="서울 -> 강원"
)
ax4.plot(
    df_3.columns,
    df_3.loc["전라남도"],
    marker="o",
    markerfacecolor="orange",
    markersize=10,
    color="yellow",
    linewidth=2,
    label="서울 -> 전남"
)

ax1.legend(loc="best")
ax1.set_title("서울 - > 충남", size=20)
ax1.set_xlabel("기간", size=12)
ax1.set_ylabel("이동 인구수", size=12)
ax1.set_xticklabels(df_3.columns, rotation=90)

ax2.legend(loc="best")
ax2.set_title("서울 - > 경북", size=20)
ax2.set_xlabel("기간", size=12)
ax2.set_ylabel("이동 인구수", size=12)
ax2.set_xticklabels(df_3.columns, rotation=90)

ax3.legend(loc="best")
ax3.set_title("서울 - > 강원도", size=20)
ax3.set_xlabel("기간", size=12)
ax3.set_ylabel("이동 인구수", size=12)
ax3.set_xticklabels(df_3.columns, rotation=90)

ax4.legend(loc="best")
ax4.set_title("서울 - > 전남", size=20)
ax4.set_xlabel("기간", size=12)
ax4.set_ylabel("이동 인구수", size=12)
ax4.set_xticklabels(df_3.columns, rotation=90)

plt.show()

# %%
# 함수 만들어서 그래프 그려보기

# %% [markdown]
# ---
# ### 누적그래프

# %%
# 누적 Data가 겹치는 그래프

plt.style.use("ggplot")
df_3.T.plot(
    kind="area",
    #stacked=False,
    stacked=True, # true면 겹쳐져보이고 false면 겹쳐져 보이지 않음
    alpha=0.2,
    figsize=(20,10)
)

plt.show()

# %%
# 서울에서 부산, 부산에서 서울로 이동한 인구 그래프로 그리기

# 서울에서 부산으로 이동한 인구 추출
mask = (df["전출지별"] == "서울특별시") & (df["전입지별"] == "부산광역시")
df_seoul = df[mask]
df_seoul = df_seoul.drop(["전출지별"], axis=1)
df_seoul.rename({"전입지별" : "전입지"}, axis=1, inplace=True)
df_seoul.set_index("전입지", inplace=True)
df_seoul

# 부산에서 서울로 이동한 인구 추출
mask1 = (df["전출지별"] == "부산광역시") & (df["전입지별"] == "서울특별시")
df_busan = df[mask1]
df_busan = df_busan.drop(["전출지별"], axis=1)
df_busan.rename({"전입지별" : "전입지"}, axis=1, inplace=True)
df_busan.set_index("전입지", inplace=True)
df_busan
# Out:
#         1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 서울특별시  24263  30144  18260  24251  30284  59914  43416  42685  48142  39673
#
#        ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지    ...
# 서울특별시  ...  25249  24459  23116  23016  21437  19621  20616  19441  19236
#
#         2017
# 전입지
# 서울특별시  19460
#
# [1 rows x 48 columns]

# %%
df_busan.loc["서울특별시"]
# Out:
# 1970    24263
# 1971    30144
# 1972    18260
# 1973    24251
# 1974    30284
# 1975    59914
# 1976    43416
# 1977    42685
# 1978    48142
# 1979    39673
# 1980    44197
# 1981    49939
# 1982    50295
# 1983    54700
# 1984    47422
# 1985    41464
# 1986    35910
# 1987    35328
# 1988    37368
# 1989    36986
# 1990    34978
# 1991    29020
# 1992    29619
# 1993    29378
# 1994    26852
# 1995    25525
# 1996    24721
# 1997    24872
# 1998    23220
# 1999    27100
# 2000    28564
# 2001    28366
# 2002    28049
# 2003    26569
# 2004    24266
# 2005    24941
# 2006    26831
# 2007    26951
# 2008    25249
# 2009    24459
# 2010    23116
# 2011    23016
# 2012    21437
# 2013    19621
# 2014    20616
# 2015    19441
# 2016    19236
# 2017    19460
# Name: 서울특별시, dtype: object

# %%
plt.style.use("ggplot")

fig = plt.figure(figsize=(25,10))

ax = fig.add_subplot(1,1,1)

ax.plot(
    df_seoul.columns,
    df_seoul.loc["부산광역시"],
    marker="o",
    markerfacecolor="red",
    markersize=10,
    color="pink",
    linewidth=2,
    label="서울 -> 부산"
)
ax.plot(
    df_busan.columns,
    df_busan.loc["서울특별시"],
    marker="o",
    markerfacecolor="blue",
    markersize=10,
    color="skyblue",
    linewidth=2,
    label="부산 -> 서울"
)

ax.legend(loc="best")
ax.set_title("서울 <-> 부산 인구이동", size=20)
ax.set_xlabel("기간", size=12)
ax.set_ylabel("이동 인구수", size=12)
ax.set_xticklabels(df_seoul.columns, rotation=90)
# Out:
# [Text(0, 0, '1970'),
#  Text(1, 0, '1971'),
#  Text(2, 0, '1972'),
#  Text(3, 0, '1973'),
#  Text(4, 0, '1974'),
#  Text(5, 0, '1975'),
#  Text(6, 0, '1976'),
#  Text(7, 0, '1977'),
#  Text(8, 0, '1978'),
#  Text(9, 0, '1979'),
#  Text(10, 0, '1980'),
#  Text(11, 0, '1981'),
#  Text(12, 0, '1982'),
#  Text(13, 0, '1983'),
#  Text(14, 0, '1984'),
#  Text(15, 0, '1985'),
#  Text(16, 0, '1986'),
#  Text(17, 0, '1987'),
#  Text(18, 0, '1988'),
#  Text(19, 0, '1989'),
#  Text(20, 0, '1990'),
#  Text(21, 0, '1991'),
#  Text(22, 0, '1992'),
#  Text(23, 0, '1993'),
#  Text(24, 0, '1994'),
#  Text(25, 0, '1995'),
#  Text(26, 0, '1996'),
#  Text(27, 0, '1997'),
#  Text(28, 0, '1998'),
#  Text(29, 0, '1999'),
#  Text(30, 0, '2000'),
#  Text(31, 0, '2001'),
#  Text(32, 0, '2002'),
#  Text(33, 0, '2003'),
#  Text(34, 0, '2004'),
#  Text(35, 0, '2005'),
#  Text(36, 0, '2006'),
#  Text(37, 0, '2007'),
#  Text(38, 0, '2008'),
#  Text(39, 0, '2009'),
#  Text(40, 0, '2010'),
#  Text(41, 0, '2011'),
# ...

# %%
# def aa(x,y):
#     x.columns,
#     df_seoul.loc[y],
#     marker="o",
#     markerfacecolor="red",
#     markersize=10,
#     color="pink",
#     linewidth=2,

# %% [markdown]
# ---
# ### 막대그래프

# %%
# df_33 = df_3.T['2000':]
df_33 = df_3.T.loc['2000':]
df_33
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도
# 2000  23083  14576  22832  22969
# 2001  22056  14303  22941  22457
# 2002  21155  13762  21582  18179
# 2003  24942  13938  21696  20432
# 2004  30246  13414  22071  16529
# 2005  26012  14550  20483  17049
# 2006  25986  15285  21969  17329
# 2007  28898  15448  22177  17717
# 2008  27458  15425  23668  16601
# 2009  24889  16569  23331  17468
# 2010  24522  16042  22736  16429
# 2011  24723  15818  23624  15974
# 2012  22269  15191  22332  14765
# 2013  21486  14420  20601  14187
# 2014  21473  14456  21173  14591
# 2015  22299  15113  22659  14598
# 2016  21741  14236  21590  13065
# 2017  21020  12464  21016  12426

# %%
plt.style.use('ggplot')
df_33.plot(
    kind='barh', ##<<<< barh 는 가로 막대그래프
    figsize=(20,10),
    color = ['orange','green','yellow','skyblue'],
)
plt.show()

# %% [markdown]
# ### 2010~2017년 기간동안 서울에서 각 시도로 이동한 인구의 합계를 구하여 막대그래프로 비교

# %%
# 서울에서 다른 지역으로 이동한 데이터만 추출

mask = (df["전출지별"] == "서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop(["전출지별"], axis=1)
df_seoul.rename({"전입지별" : "전입지"}, axis=1, inplace=True)
df_seoul.set_index("전입지", inplace=True)
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %%
df_4
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 전입지   ...
# 충청남도  ...  24889  24522  24723  22269  21486  21473  22299  21741  21020
# 경상북도  ...  16569  16042  15818  15191  14420  14456  15113  14236  12464
# 강원도   ...  23331  22736  23624  22332  20601  21173  22659  21590  21016
# 전라남도  ...  17468  16429  15974  14765  14187  14591  14598  13065  12426
#
#              합계
# 전입지
# 충청남도  1529273.0
# 경상북도  1052175.0
# 강원도   1146275.0
# 전라남도  1381657.0
#
# [4 rows x 49 columns]

# %%
# df_4.loc['전국']
df_4.drop('전국',axis='rows', inplace=True)
df_4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[210], line 2
#       1 # df_4.loc['전국']
# ----> 2 df_4.drop('전국',axis='rows', inplace=True)
#       3 df_4
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
# df_4.T.loc['2010':'2017'][['충청남도','강원도','경상북도','전라남도']]
# df_44.sort_values()[::-1]
#df.sum(axis='rows')
df_44 = df_4.T.loc['2010':'2017'][['충청남도','강원도','경상북도','전라남도']].sum(axis='rows')

# %%
df_444 = pd.DataFrame(df_44)
df_444['합계'] = df_44[0:4]
df_444.drop(0,axis='columns', inplace=True)
df_444
# Out:
#           합계
# 전입지별
# 충청남도  179533
# 강원도   175731
# 경상북도  117740
# 전라남도  116035

# %%
df_444.drop(0,axis='columns', inplace=True)
df_444
# Out:
#           합계
# 전입지별
# 충청남도  179533
# 강원도   179533
# 경상북도  179533
# 전라남도  179533

# %%
df_444.sort_values
# Out:
# <bound method DataFrame.sort_values of           합계
# 전입지별
# 충청남도  179533
# 강원도   175731
# 경상북도  117740
# 전라남도  116035>

# %%
plt.style.use('ggplot')

fig = plt.figure(figsize=(25,10))

ax = fig.add_subplot(1,1,1)

df_444.sort_values().plot(
    kind='barh', ##<<<< barh 는 가로 막대그래프
    figsize=(20,10),
    color = ['blue'],
)

# ax.legend(loc=(1,175000))
ax.set_title("서울->타시도 인구 이동", size=20)
ax.set_xlabel("이동 인구수", size=12)
ax.set_ylabel("전입지", size=12)
ax.legend(loc="best")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 7
#       3 fig = plt.figure(figsize=(25,10))
#       5 ax = fig.add_subplot(1,1,1)
# ----> 7 df_444.sort_values().plot(
#       8     kind='barh', ##<<<< barh 는 가로 막대그래프
#       9     figsize=(20,10),
#      10     color = ['blue'],
#      11 )
#      13 # ax.legend(loc=(1,175000))
#      14 ax.set_title("서울->타시도 인구 이동", size=20)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### 강사님 답안

# %%
col_years = list(map(str,range(2010,2018)))
df_4 = df_seoul.loc[['충청남도','경상북도','강원도','전라남도']]
df_4.head()
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %%
df_seoul
# Out:
#         1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 부산광역시  11568  11130  11768  16307  22220  27515  23732  27213  29856  28542
#
#        ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지    ...
# 부산광역시  ...  17353  17738  17418  18816  16135  16153  17320  17009  15062
#
#         2017
# 전입지
# 부산광역시  14484
#
# [1 rows x 48 columns]

# %% [markdown]
# 젠장.. 막혓따 ..

# %%
# 합계
df_4['합계'] = df_4.sum(axis=1)

# %%
# 오름차순 정렬
df_total = df_4[['합계']].sort_values(by='합계', ascending=True)
df_total.head()
# Out:
#              합계
# 전입지
# 경상북도  1052175.0
# 강원도   1146275.0
# 전라남도  1381657.0
# 충청남도  1529273.0

# %%
plt.style.use('ggplot')

df_total.plot(
    kind='barh',
    color = 'cornflowerblue',
    figsize=(10,5),
)
plt.title('서울 -> 타시도 인구 이동')
plt.ylabel('전입지')
plt.xlabel('이동 인구수')
plt.show()

# %% [markdown]
# ---
# ### 2개의 y축을 갖는 그래프 작성
# - 남북한 발전량
# - 막대그래프는 북한의 발전량
# - 선 그래프는 북한 발전량의 전년대비 증감률을 백분율로 표시
