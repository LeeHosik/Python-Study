# %% [markdown]
# ### Seaborn - HighQuality Graph
# - Matplotlib의 기능과 스타일을 확장한 파이썬 시각 도구의 고급버전

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_style('darkgrid')

# %%
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# 1  regplot = regression
sns.regplot(
    x = 'age',
    y = 'fare',
    data = titanic,
    scatter_kws = {'color' : 'black'}, # scatter color
    line_kws = {'color':'red'}, # regression line color
    # alpha = 0.3, # 앤 안되네
    fit_reg = True, # < default value
    ax = ax1
)

# 2  fit_reg = False
sns.regplot(
    x = 'age',
    y = 'fare',
    data = titanic,
    scatter_kws = {'color' : 'blue'}, # scatter color
    # line_kws = {'color':'red'}, # regression line color
    # alpha = 0.3, # 앤 안되네
    fit_reg = False, # < default value
    ax = ax2
)
plt.show()

# %% [markdown]
# ---
# ### Histogram / Kernel Density Estimation(KDE) 커널 밀도 그래프
# : (KDE)는 그래프와 x축 사이의 면적이 1이 되도록 그리는 밀도 분포 함수

# %%
# 
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

# distplot(Histogram / kernel Density)
sns.distplot(titanic['fare'],ax = ax1) # 상대분포 
ax1.set_title('titanic fare - distplot')
# 
# kdeplot (kernel density)
sns.kdeplot(x = 'fare', data = titanic, ax = ax2)
ax2.set_title('titanic fare - kdeplot')

# histogram
sns.histplot(x = 'fare' , data = titanic, ax = ax3 )
ax3.set_title('titanic fare - histplot')

plt.show()

# %% [markdown]
# fare는 $100 미만에 집중되어 있다.

# %% [markdown]
# ---
# ### Heat Map
# - 2개의 범주형 변수를 각각 x,y 축에 놓고 데이터를 매트릭스 형태로 분류

# %%
table = titanic.pivot_table(index = ['sex'], columns=['class'], aggfunc='size')
# aggfunc = 'size' : data값의 크기를 기준으로 집계 한다. count 해주는거라고 생각해도 될듯 .? 
table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 table = titanic.pivot_table(index = ['sex'], columns=['class'], aggfunc='size')
#       2 # aggfunc = 'size' : data값의 크기를 기준으로 집계 한다. count 해주는거라고 생각해도 될듯 .?
#       3 table
#
# NameError: name 'titanic' is not defined

# %%
sns.heatmap(
    table,
    annot=True, # 숫자가 보임 
    fmt = 'd', # 숫자에 지수 나오면 지수 말고 숫자로 보여주는녀석 
    # format = 'd' # format으로는 안되고 fmt로 써야댐
    cmap='YlGnBu', # Yellow,Green, Blue
    # linewidths=50, # 떨궈주는 사이즈 
    linewidths=0.5, # 보통은 0.5 정도
    cbar = True # default True 오른쪽 color bar, 안보일라면 False
)
plt.show()

# %% [markdown]
# Theme : darkgrid, whitegrid, dark, white, ticks
# sns의 내장 기본 5가지 theme

# %% [markdown]
# ---
# ### 범주형 데이터의 산점도

# %%
sns.set_style('whitegrid')

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.stripplot(
    x = 'class',
    y = 'age',
    data = titanic,
    ax = ax1,
    hue = 'class',
)
sns.swarmplot(
    x = 'class',
    y = 'age',
    data = titanic,
    ax = ax2,
    hue = 'class',
)

ax1.set_title('Strip Plot')
ax2.set_title('Swarm Plot')

ax1.legend(loc='upper right', fontsize = 6)
plt.show()

# %% [markdown]
# ---
# ### 오차 bar chart

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

sns.barplot( # bar 꼭다리 선은 표준오차 범위를 나타내줌
    x = 'sex',
    y = 'survived',
    data = titanic,
    ax = ax1,
    # ci = 'sd' # 표준오차를 표준편차로 바꾸겠다
)
sns.barplot( # bar 꼭다리 선은 표준오차 범위를 나타내줌
    x = 'sex',
    y = 'survived',
    data = titanic,
    hue = 'class',
    ax = ax2,
)
sns.barplot( # bar 꼭다리 선은 표준오차 범위를 나타내줌
    x = 'sex',
    y = 'survived',
    data = titanic,
    hue = 'class',
    dodge = False,
    ax = ax3,
)


plt.show()

# %% [markdown]
# ---
# ### 빈도 그래프

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

sns.countplot(
    x = 'class',
    data = titanic,
    palette = 'Set1',
    ax = ax1
)

sns.countplot(
    x = 'class',
    data = titanic,
    hue = 'who',
    palette = 'Set2',
    ax = ax2
)
sns.countplot(
    x = 'class',
    data = titanic,
    hue = 'who',
    palette = 'Set3',
    dodge = False,
    ax = ax3
)

plt.show()

# %% [markdown]
# ---
# ### Box Plot / violin graph
# - box plot은 범주형 데이터의 분포와 주요 통계 지표를 제공하지만, 데이터가 퍼져있는 정도(분산의정도)알기 어렵다
# - violin graph : box plot + Kernel Density Estimation(KDE)

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

sns.boxplot(
    x = 'alive',
    y = 'age',
    data = titanic,
    ax = ax1
)
sns.boxplot(
    x = 'alive',
    y = 'age',
    hue = 'sex',
    data = titanic,
    ax = ax2
)

# violin default
sns.violinplot(
    x = 'alive',
    y = 'age',
    data = titanic,
    ax = ax3
)
sns.violinplot(
    x = 'alive',
    y = 'age',
    hue = 'sex',
    data = titanic,
    ax = ax4
)

plt.show()

# %% [markdown]
# ---
# ### joint graph
#  - 산점도를 기본으로 하고 각 축에 대한 histogram을 동시 제공

# %%
# joint graph - 산점도 (default)
j1 = sns.jointplot(
    x = 'fare',
    y = 'age',
    data = titanic,
)
j1.fig.suptitle('titianic fare - scatter',size = 15)
plt.show()

# %%
# joint graph - 회귀선
j2 = sns.jointplot(
    x = 'fare',
    y = 'age',
    data = titanic,
    kind = 'reg'
)
j2.fig.suptitle('titianic fare - reg',size = 15)
plt.show()

# %%
# joint graph - 육각그래프
j3 = sns.jointplot(
    x = 'fare',
    y = 'age',
    data = titanic,
    kind = 'hex'
)
j3.fig.suptitle('titianic fare - hexa',size = 15)
plt.show()

# %%
# joint graph - 커널 밀집 그래프 
j4 = sns.jointplot(
    x = 'fare',
    y = 'age',
    data = titanic,
    kind = 'kde'
)
j4.fig.suptitle('titianic fare - kde',size = 15)
plt.show()

# %% [markdown]
# ---
# ### 조건을 적용하여 호면을 그리드로 분할하기

# %%
g = sns.FacetGrid(
    data = titanic,
    col = 'who', # color X , column O
    row = 'survived'
)

g.map(plt.hist, 'age')
plt.show()

# %% [markdown]
# ---
# ### 이변수 데이터의 분포
# - matrix 형태로 짝을 지어 표현

# %%
titanic_pair = titanic[['age','pclass','fare']]
sns.pairplot(titanic_pair)
plt.show()
