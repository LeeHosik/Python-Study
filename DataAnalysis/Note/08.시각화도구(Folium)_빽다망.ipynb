# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import folium
warnings.filterwarnings("ignore")

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
df = pd.read_csv('../Data/UpgradePaiksCoffee.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Area      1260 non-null   object
#  1   ShopName  1260 non-null   object
#  2   Address   1260 non-null   object
#  3   lng       1260 non-null   object
#  4   lat       1260 non-null   object
# dtypes: object(5)
# memory usage: 49.3+ KB

# %%
# df['lat'] = pd.to_numeric(df['lat'])
df[['lng','lat']] = df[['lng','lat']].apply(pd.to_numeric, errors = 'coerce')

# %%
# Map 만들기
PaiksCoffee = folium.Map(
    location = [37.55, 126.98], 
    tiles = 'Stamen Terrain', 
    # tiles = 'Stamen Toner', 
    zoom_start = 12
    )

for name, lat, lng in zip(df.ShopName, df.lat, df.lng):
    try:
        folium.CircleMarker([lat, lng],
                            radius = 5,
                            color = 'brown',
                            fill = True,
                            fill_color = 'coral',
                            fill_opacity = 0.7,
                            popup = name).add_to(PaiksCoffee)
    except:print(f'{name} error')
    


PaiksCoffee
# Out:
# 인천아인여성병원점 error
# 철원와수리점 error
# 수원고색산업단지점 error
# 천안두정대림포레점 error
# 범계에이스점 error
# 세종반곡점 error
# 청주개신점 error
# 고양향동점 error
# 오창과학단지점 error
# 대구서구청점 error
# 무안오룡점 error
# 전주하가점 error
# 인천굴포천2호점 error
# 남원중앙점 error
# 구리갈매역중앙점 error
# 동두천지행역점 error
# 경남거창중앙점 error
# 울산달동1호점 error
# 천안상명대점 error
# 공덕역새창로점 error
# 대구반월당지하점 error
# 부평청천중점 error
# 부천원종중앙점 error
# 부천역CGV점 error
# 부천상지초교점 error
# 부산정관동오점 error
# 부산서면롯데점 error
# 부산서면교육센터점 error
# 상동역푸른마을점 error
# 분당서현교보점 error
# 송내역남부점 error
# 송내역법조타운점 error
# 안산본오주공점 error
# 압구정역점 error
# 안양비산점 error
# 안암역점 error
# 오산시청점 error
# 제주노형뜨란채점 error
# 창원시티세븐점 error
# 대전중앙로지하점 error
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac44924bf28b475bfaca5ec9e6a3e857 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac44924bf28b475bfaca5ec9e6a3e857&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac44924bf28b475bfaca5ec9e6a3e857 = L.map(
#                 &quot;map_ac44924bf28b475bfaca5ec9e6a3e857&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2f051deb063a988849db16d5149ed97 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac44924bf28b475bfaca5ec9e6a3e857);
#
#
#             var circle_marker_388d5516b2369daacf865ed1e3770f5c = L.circleMarker(
#                 [37.2090838, 126.8183638],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ac44924bf28b475bfaca5ec9e6a3e857);
#
#
#         var popup_3da9f8b9e74b9d84b7a72d5efbde8a95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5194be728ab324be0638d65c4c231178 = $(`&lt;div id=&quot;html_5194be728ab324be0638d65c4c231178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화성남양시장점&lt;/div&gt;`)[0];
#                 popup_3da9f8b9e74b9d84b7a72d5efbde8a95.setContent(html_5194be728ab324be0638d65c4c231178);
#
#
#
#         circle_marker_388d5516b2369daacf865ed1e3770f5c.bindPopup(popup_3da9f8b9e74b9d84b7a72d5efbde8a95)
#         ;
#
#
#
#
#             var circle_marker_62f09803c4a66b59388c374983b85316 = L.circleMarker(
#                 [35.853828, 128.6206986],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ac44924bf28b475bfaca5ec9e6a3e857);
#
#
#         var popup_a6847d3711874f70e5e23b54d3ff3cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c1d8dc951f676b76cef67bfc3e4a9e6 = $(`&lt;div id=&quot;html_0c1d8dc951f676b76cef67bfc3e4a9e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대구수성3가점&lt;/div&gt;`)[0];
#                 popup_a6847d3711874f70e5e23b54d3ff3cab.setContent(html_0c1d8dc951f676b76cef67bfc3e4a9e6);
#
#
#
#         circle_marker_62f09803c4a66b59388c374983b85316.bindPopup(popup_a6847d3711874f70e5e23b54d3ff3cab)
#         ;
#
#
#
#
#             var circle_marker_4802bcf59150ef15a1861de7c0b922b5 = L.circleMarker(
#                 [35.8448231, 127.1536639],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ac44924bf28b475bfaca5ec9e6a3e857);
#
#
#         var popup_fa4ddc3bd67fa103ed09f47458c5ea1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efae66ca64ebcf3dddf6383579ff6169 = $(`&lt;div id=&quot;html_efae66ca64ebcf3dddf6383579ff6169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;전주대자인병원점&lt;/div&gt;`)[0];
#                 popup_fa4ddc3bd67fa103ed09f47458c5ea1c.setContent(html_efae66ca64ebcf3dddf6383579ff6169);
#
#
#
#         circle_marker_4802bcf59150ef15a1861de7c0b922b5.bindPopup(popup_fa4ddc3bd67fa103ed09f47458c5ea1c)
#         ;
#
#
#
#
#             var circle_marke
