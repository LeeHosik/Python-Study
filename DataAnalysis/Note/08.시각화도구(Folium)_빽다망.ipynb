# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import folium
warnings.filterwarnings("ignore")

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
df = pd.read_csv('../Data/UpgradePaiksCoffee.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Area      1260 non-null   object
#  1   ShopName  1260 non-null   object
#  2   Address   1260 non-null   object
#  3   lng       1260 non-null   object
#  4   lat       1260 non-null   object
# dtypes: object(5)
# memory usage: 49.3+ KB

# %%
df[['lng','lat']] = df[['lng','lat']].apply(pd.to_numeric, errors = 'coerce')

# %%
# Map 만들기
error=[]
PaiksCoffee = folium.Map(
    location = [37.55, 126.98], 
    tiles = 'Stamen Terrain', 
    # tiles = 'Stamen Toner', 
    zoom_start = 12
    )

for name, lat, lng in zip(df.ShopName, df.lat, df.lng):
    try:
        folium.CircleMarker([lat, lng],
                            radius = 5,
                            color = 'brown',
                            fill = True,
                            fill_color = 'coral',
                            fill_opacity = 0.7,
                            popup = name).add_to(PaiksCoffee)
    except: error.append(name)
PaiksCoffee
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_780863ed55b4404e236be012110f3782 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_780863ed55b4404e236be012110f3782&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_780863ed55b4404e236be012110f3782 = L.map(
#                 &quot;map_780863ed55b4404e236be012110f3782&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4672500acda378ba4323514a5420ca7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_780863ed55b4404e236be012110f3782);
#
#
#             var circle_marker_b293633165573f6fe8598a401c4a613a = L.circleMarker(
#                 [37.2090838, 126.8183638],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_780863ed55b4404e236be012110f3782);
#
#
#         var popup_70b212305a7d7ea19b715f1b12e952b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a3f350ef61d83be0a946af72d58ebbf = $(`&lt;div id=&quot;html_0a3f350ef61d83be0a946af72d58ebbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화성남양시장점&lt;/div&gt;`)[0];
#                 popup_70b212305a7d7ea19b715f1b12e952b4.setContent(html_0a3f350ef61d83be0a946af72d58ebbf);
#
#
#
#         circle_marker_b293633165573f6fe8598a401c4a613a.bindPopup(popup_70b212305a7d7ea19b715f1b12e952b4)
#         ;
#
#
#
#
#             var circle_marker_596df0edab403564e2f1b4f20378254d = L.circleMarker(
#                 [35.853828, 128.6206986],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_780863ed55b4404e236be012110f3782);
#
#
#         var popup_bde333d297b54fdd85f65673a6adf90a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c7f2ff56dd4b8ef10b6e0a55b15de47 = $(`&lt;div id=&quot;html_5c7f2ff56dd4b8ef10b6e0a55b15de47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대구수성3가점&lt;/div&gt;`)[0];
#                 popup_bde333d297b54fdd85f65673a6adf90a.setContent(html_5c7f2ff56dd4b8ef10b6e0a55b15de47);
#
#
#
#         circle_marker_596df0edab403564e2f1b4f20378254d.bindPopup(popup_bde333d297b54fdd85f65673a6adf90a)
#         ;
#
#
#
#
#             var circle_marker_d4d232fa60365e13b732bc7d28331e3d = L.circleMarker(
#                 [35.8448231, 127.1536639],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_780863ed55b4404e236be012110f3782);
#
#
#         var popup_c7c533944773cb79c79728877f1a90a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2dd429a16587636223e73283c2f52001 = $(`&lt;div id=&quot;html_2dd429a16587636223e73283c2f52001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;전주대자인병원점&lt;/div&gt;`)[0];
#                 popup_c7c533944773cb79c79728877f1a90a8.setContent(html_2dd429a16587636223e73283c2f52001);
#
#
#
#         circle_marker_d4d232fa60365e13b732bc7d28331e3d.bindPopup(popup_c7c533944773cb79c79728877f1a90a8)
#         ;
#
#
#
#
#             var circle_marke

# %%
print(len(error))
print(error[:5])
# Out:
# 40
# ['인천아인여성병원점', '철원와수리점', '수원고색산업단지점', '천안두정대림포레점', '범계에이스점']

# %%
df[df.ShopName=='인천아인여성병원점']
# Out:
#     Area   ShopName                              Address  lng  lat
# 3  인천광역시  인천아인여성병원점  인천광역시 미추홀구 주안동 포레나미추홀 201동 1층 1032호  NaN  NaN
