# %%
import urllib.request as req

# %%
fileName = "mov01.jpg"

URL = "https://zeushahn.github.io/Test/images/" + fileName
saveName = "../Data/" + fileName

req.urlretrieve(URL, saveName)
print("OK")
# Out:
# OK

# %%
# mov02.jpg, mov03.jpg, mov04.jpg 의 이미지 여러개를 한꺼번에 가져오기
num = 1
while True:
    num = str(num)
    str = 'mov0'
    jpg = '.jpg'
    URL = "https://zeushahn.github.io/Test/images/" + str + num +jpg
    saveName = "../Data/" + str + num +jpg
    req.urlretrieve(URL, saveName)
    num = int(num)
    num += 1
    print(f'{str+num} OK')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       2 num = 1
#       3 while True:
# ----> 4     num = str(num)
#       5     str = 'mov0'
#       6     jpg = '.jpg'
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### 기상청
# stnId(지역번호)
# - 전국 : 108
# - 서울/경기도 : 109
# - 강원도 : 105
# - 전라북도  146
# - 전라남도 :156
# - 제주특별자치도 : 184

# %%
# 서울 경기 
stnId = '109'
URL = "https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=" + stnId

data = req.urlopen(URL).read().decode("utf-8")

print(data)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2023년 01월 18일 (수)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2023년 01월 18일 (수)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202301180600</tm>
# ...
