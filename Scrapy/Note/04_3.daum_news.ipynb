# %%
from bs4 import BeautifulSoup
import urllib.request as req

import webbrowser
import time

# %% [markdown]
# ---
# ### 다음 뉴스

# %%
url = 'https://news.daum.net/digital#1'
res = req.urlopen(url)

# BeautifulSoup으로 분석하기

soup = BeautifulSoup(res, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="IT" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/digital" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>IT | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/5c015e8/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/5c015e8/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major

body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major > ul > li:nth-child(7) > strong > span

# %%
newstitles = soup.select(".list_newsmajor a")
newslinks=[]
i = 1
for newstitle in newstitles:
    newslinks.append(newstitle.attrs['href'])
    print(f'{newstitle.string}')
    
    i+=1
  
print(newslinks)
# Out:
# 들으면 잠드는 수면 음악의 비밀[유용하 기자의 사이언스 톡]
# "애플, 아이패드와 닮은 가정용 디스플레이 개발 중"
# 아마존·MS 2.8만명 추가 해고…美 빅테크 감원 6만명 돌파
# '손 안의 작은 천문대' 나쫌…"타이레놀 같은 채널"[튜브가이드④]
# 메타·아마존 이어... MS도 내달까지 1만명 대량 해고
# [알짜배기 지식재산]아이디어 분출하는 AI…권리 보호는?
# 가상자산 주석  공시 의무화…"회계 기준 정비돼야"
# 가상자산 '김프' 악용 범죄, 트래블룰 공백·은행 모럴해저드가 피해 키웠다
# 똑딱이 디카, 플립폰에 빠진 MZ… “스마트폰서 벗어나고파”
# 빗썸, NH농협은행 실명계좌 환승할까…차기 제휴 은행 물색
# ['https://v.daum.net/v/20230119050349415', 'https://v.daum.net/v/20230119084554421', 'https://v.daum.net/v/20230119083041069', 'https://v.daum.net/v/20230119080017530', 'https://v.daum.net/v/20230119074151203', 'https://v.daum.net/v/20230119061154110', 'https://v.daum.net/v/20230119073503085', 'https://v.daum.net/v/20230119073004016', 'https://v.daum.net/v/20230119072711977', 'https://v.daum.net/v/20230119072004884']

# %%
#news=[]
for news in newslinks:
# BeautifulSoup으로 분석하기
    
    res = req.urlopen(news)
    soup = BeautifulSoup(res, "html.parser")
    new = soup.select(".list_newsmajor a")
    title = soup.select_one(".tit_view").text
    time.sleep(1)

newslinks

# %%
url = 'https://v.daum.net/v/20230119050349415'
res = req.urlopen(url)

# BeautifulSoup으로 분석하기

soup = BeautifulSoup(res, "html.parser")

# %%
#mArticle > div.head_view > h3

# %%
title = soup.select_one(".tit_view").text
print(f'{titles}')
# Out:
# 들으면 잠드는 수면 음악의 비밀[유용하 기자의 사이언스 톡]
